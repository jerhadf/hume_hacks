# %%
import audb

audb.available(only_latest=True)
# Out:
#                          backend                                    host  \
# name
# air                  artifactory  https://audeering.jfrog.io/artifactory
# cough-speech-sneeze  artifactory  https://audeering.jfrog.io/artifactory
# crema-d              artifactory  https://audeering.jfrog.io/artifactory
# emodb                artifactory  https://audeering.jfrog.io/artifactory
# micirp               artifactory  https://audeering.jfrog.io/artifactory
# musan                artifactory  https://audeering.jfrog.io/artifactory
# vadtoolkit           artifactory  https://audeering.jfrog.io/artifactory
#
#                       repository version
# name
# air                  data-public   1.4.2
# cough-speech-sneeze  data-public   2.0.1
# crema-d              data-public   1.2.0
# emodb                data-public   1.4.1
# micirp               data-public   1.0.0
# musan                data-public   1.0.0
# vadtoolkit           data-public   1.1.0

# %%
# load version 1 of emodb database (https://github.com/audeering/emodb - Berlin Database of Emotional Speech)
db = audb.load("emodb", version="1.4.1", verbose=False)
