# %%
import pandas as pd

# read the csv file
df = pd.read_csv('Campaign report.csv')

df
# Out:
#   Campaign status                                  Campaign Budget name  \
# 0         Enabled              Affective Computing Datasets          --
# 1         Enabled                   Facial Expression Model          --
# 2         Enabled  Vocal Expression Description Model + API          --
# 3         Enabled              Vocal Expression Model + API          --
# 4         Enabled       https://hume.ai/products/sentiment/          --
# 5         Enabled             Science-Backed Empathic AI/ML          --
# 6         Enabled                Speech Prosody Model + API          --
# 7         Enabled            Automated Facial Action Coding          --
# 8         Enabled              Language Emotion Model + API          --
# 9         Enabled                                  Toxicity          --
#
#   Currency code  Budget Budget type                  Bid strategy type  \
# 0           USD   12.00       Daily                    Maximize clicks
# 1           USD   51.00       Daily  Maximize Conversions (Target CPA)
# 2           USD   15.00       Daily               Maximize Conversions
# 3           USD   86.55       Daily  Maximize Conversions (Target CPA)
# 4           USD   20.00       Daily               Maximize Conversions
# 5           USD    6.00       Daily                    Maximize clicks
# 6           USD  100.00       Daily  Maximize Conversions (Target CPA)
# 7           USD    4.00       Daily                    Maximize clicks
# 8           USD   50.00       Daily                    Maximize clicks
# 9           USD   20.00       Daily               Maximize Conversions
#
#                Status              Status reasons Campaign type       Impr.  \
# 0            Eligible                         NaN         Smart   3,425,262
# 1  Eligible (Limited)  limited by budget; unknown        Search     511,852
# 2            Eligible                     unknown        Search      20,821
# 3            Eligible                     unknown        Search     142,782
# 4            Eligible                     unknown        Search     318,675
# 5            Eligible                         NaN         Smart   1,520,959
# 6  Eligible (Limited)  limited by budget; unknown        Search     342,687
# 7            Eligible                         NaN         Smart   1,903,181
# 8            Eligible                         NaN         Smart  11,317,486
# 9            Eligible                     unknown        Search      39,721
#
#   Interactions Interaction rate  Avg. cost      Cost
# 0       34,382            1.00%       0.18   6253.69
# 1       27,961            5.46%       0.62  17473.05
# 2          789            3.79%       4.83   3807.51
# 3       15,144           10.61%       1.09  16441.17
# 4       11,978            3.76%       0.60   7206.93
# 5       18,015            1.18%       0.17   3124.95
# 6       42,666           12.45%       0.91  38718.15
# 7       43,540            2.29%       0.05   2253.25
# 8      133,953            1.18%       0.20  26129.02
# 9        2,763            6.96%       3.34   9241.11

# %%
# convert interaction rate to float for calculation
df['Interaction rate'] = df['Interaction rate'].str.rstrip('%').astype('float') / 100.0

# calculate the average interaction rate
average_interaction_rate = df['Interaction rate'].mean()

average_interaction_rate
# Out:
# 0.048679999999999994
